# %%
import kagglehub
import pandas as pd

# Download latest version of the dataset
path = kagglehub.dataset_download("yakhyojon/tiktok")
print("Path to dataset files:", path)

# Note: We will load the CSV into a pandas dataframe in the next step
